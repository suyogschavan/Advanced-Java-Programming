# %%
import mne
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn-bright') # Plot Style
plt.rcParams['figure.dpi'] = 300 # DPI setting
plt.rcParams['figure.figsize'] = (8, 6)

# %%
# Data import
raw_h = mne.io.read_raw_edf("h01.edf", preload=True)# Import data file into workspace
# h01 specifies the EEG record of healthy control-1
# Out:
# Extracting EDF parameters from h:\DOCUMENTS\Nothing\CAPSTONE\h01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...

# %%
# raw_s = mne.io.read_raw_edf("h01.edf", preload=True)# Import data file into workspace
# s01 specifies the EEG record of SZ patient-1

# Give the sample rate
print('sample rate:', raw_h.info['sfreq'], 'Hz')
# Out:
# Extracting EDF parameters from h:\DOCUMENTS\Nothing\CAPSTONE\h01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# sample rate: 160.0 Hz

# %%
print('Data matrix size : %s channels x %s samples' % (raw_h.info['nchan'], len(raw_h.times)))
# Out:
# Data matrix size : 64 channels x 20000 samples

# %%
print('Channel names:', raw_h.info['ch_names'])
# Out:
# Channel names: ['Fc5.', 'Fc3.', 'Fc1.', 'Fcz.', 'Fc2.', 'Fc4.', 'Fc6.', 'C5..', 'C3..', 'C1..', 'Cz..', 'C2..', 'C4..', 'C6..', 'Cp5.', 'Cp3.', 'Cp1.', 'Cpz.', 'Cp2.', 'Cp4.', 'Cp6.', 'Fp1.', 'Fpz.', 'Fp2.', 'Af7.', 'Af3.', 'Afz.', 'Af4.', 'Af8.', 'F7..', 'F5..', 'F3..', 'F1..', 'Fz..', 'F2..', 'F4..', 'F6..', 'F8..', 'Ft7.', 'Ft8.', 'T7..', 'T8..', 'T9..', 'T10.', 'Tp7.', 'Tp8.', 'P7..', 'P5..', 'P3..', 'P1..', 'Pz..', 'P2..', 'P4..', 'P6..', 'P8..', 'Po7.', 'Po3.', 'Poz.', 'Po4.', 'Po8.', 'O1..', 'Oz..', 'O2..', 'Iz..']

# %%
raw_h.plot(start=300, duration=2, block=True, show=False, color='green')
# Out:
# Using matplotlib as 2D backend.
# C:\Users\Suyog_Asus\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\viz\_figure.py:343: RuntimeWarning: Mean of empty slice.
#   data -= data.mean(axis=1, keepdims=True)
# C:\Users\Suyog_Asus\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\SUYOG_~1\AppData\Local\Temp/ipykernel_14632/364897381.py in <module>
# ----> 1 raw_h.plot(start=300,duration=2, block=True, show=False, color='green')
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\base.py in plot(self, events, duration, start, n_channels, bgcolor, color, bad_color, event_color, scalings, remove_dc, order, show_options, title, show, block, highpass, lowpass, filtorder, clipping, show_first_samp, proj, group_by, butterfly, decim, noise_cov, event_id, show_scrollbars, show_scalebars, time_format, precompute, use_opengl, verbose)
#    1534              show_scrollbars=True, show_scalebars=True, time_format='float',
#    1535              precompute='auto', use_opengl=None, verbose=None):
# -> 1536         return plot_raw(self, events, duration, start, n_channels, bgcolor,
#    1537                         color, bad_color, event_color, scalings, remove_dc,
#    1538                         order, show_options, title, show, block, highpass,
#
# <decorator-gen-174> in plot_raw(raw, events, duration, start, n_channels, bgcolor, color, bad_color, event_color, scalings, remove_dc, order, show_options, title, show, block, highpass, lowpass, filtorder, clipping, show_first_samp, proj, group_by, butterfly, decim, noise_cov, event_id, show_scrollbars, show_scalebars, time_format, precompute, use_opengl, verbose)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\viz\raw.py in plot_raw(raw, events, duration, start, n_channels, bgcolor, color, bad_color, event_color, scalings, remove_dc, order, show_options, title, show, block, highpass, lowpass, filtorder, clipping, show_first_samp, proj, group_by, butterfly, decim, noise_cov, event_id, show_scrollbars, show_scalebars, time_format, precompute, use_opengl, verbose)
#     380
#     381     # Draw Plot
# --> 382     fig._redraw(update_data=True, annotations=True)
#     383
#     384     # start with projectors dialog open, if requested
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\viz\_mpl_figure.py in _redraw(self, update_data, annotations)
#    1849     def _redraw(self, update_data=True, annotations=False):
#    1850         """Redraw (convenience method for frequently grouped actions)."""
# -> 1851         super()._redraw(update_data, annotations)
#    1852         if self.mne.vline_visible and self.mne.is_epochs:
#    1853             # prevent flickering
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\viz\_figure.py in _redraw(self, update_data, annotations)
#     381         """Redraws backend if necessary."""
#     382         if update_data:
# --> 383             self._update_data()
#     384
#     385         self._draw_traces()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\viz\_figure.py in _update_data(self)
#     369         data, times = self._load_data(start, stop)
#     370         # process the data
# --> 371         data = self._process_data(data, start, stop, self.mne.picks)
#     372         # set the data as attributes
#     373         self.mne.data = data
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\viz\_figure.py in _process_data(self, data, start, stop, picks, signals)
#     357                                        invert=True))
#     358         norms = np.vectorize(self.mne.scalings.__getitem__)(this_types)
# --> 359         norms[stims] = data[stims].max(axis=-1)
#     360         norms[white] = self.mne.scalings['whitened']
#     361         norms[norms == 0] = 1
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py in _amax(a, axis, out, keepdims, initial, where)
#      38 def _amax(a, axis=None, out=None, keepdims=False,
#      39           initial=_NoValue, where=True):
# ---> 40     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#      41
#      42 def _amin(a, axis=None, out=None, keepdims=False,
#
# ValueError: zero-size array to reduction operation maximum which has no identity
# <MNEBrowseFigure size 2400x2400 with 4 Axes>
