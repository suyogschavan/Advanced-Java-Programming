# %%
import mne

# %%
mne.__version__
# Out:
# '0.24.1'

# %%
raw = mne.io.read_raw_edf("S001R04.edf", preload=True)
# Out:
# Extracting EDF parameters from H:\DOCUMENTS\Nothing\CAPSTONE\CAP\S001R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...

# %%
mne.set_log_level("WARNING")

# %%
raw
# Out:
# <RawEDF | S001R04.edf, 64 x 20000 (125.0 s), ~9.8 MB, data loaded>

# %%
raw.info
# Out:
# <Info | 7 non-empty values
#  bads: []
#  ch_names: Fc5., Fc3., Fc1., Fcz., Fc2., Fc4., Fc6., C5.., C3.., C1.., ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 80.0 Hz
#  meas_date: 2009-08-12 16:15:00 UTC
#  nchan: 64
#  projs: []
#  sfreq: 160.0 Hz
# >

# %%
raw.info["sfreq"]
# Out:
# 160.0

# %%
raw.rename_channels(lambda s: s.strip("."))
# Out:
# <RawEDF | S001R04.edf, 64 x 20000 (125.0 s), ~9.8 MB, data loaded>

# %%
mne.channels.get_builtin_montages()
# Out:
# ['EGI_256',
#  'GSN-HydroCel-128',
#  'GSN-HydroCel-129',
#  'GSN-HydroCel-256',
#  'GSN-HydroCel-257',
#  'GSN-HydroCel-32',
#  'GSN-HydroCel-64_1.0',
#  'GSN-HydroCel-65_1.0',
#  'biosemi128',
#  'biosemi16',
#  'biosemi160',
#  'biosemi256',
#  'biosemi32',
#  'biosemi64',
#  'easycap-M1',
#  'easycap-M10',
#  'mgh60',
#  'mgh70',
#  'standard_1005',
#  'standard_1020',
#  'standard_alphabetic',
#  'standard_postfixed',
#  'standard_prefixed',
#  'standard_primed',
#  'artinis-octamon',
#  'artinis-brite23']

# %%
montage = mne.channels.make_standard_montage("standard_1020")
montage.plot()
# Out:
# 4 duplicate electrode labels found:
# T7/T3, T8/T4, P7/T5, P8/T6
# Plotting 90 unique labels.
# Creating RawArray with float64 data, n_channels=90, n_times=1
#     Range : 0 ... 0 =      0.000 ...     0.000 secs
# Ready.

# %%
raw.set_montage(montage, match_case=False)
# Out:
# <RawEDF | S001R04.edf, 64 x 20000 (125.0 s), ~9.9 MB, data loaded>

# %%
raw.set_eeg_reference("average")
# Out:
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# <RawEDF | S001R04.edf, 64 x 20000 (125.0 s), ~9.8 MB, data loaded>

# %%
raw.annotations
# Out:
# <Annotations | 30 segments: T0 (15), T1 (8), T2 (7)>

# %%
raw.plot()
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 576x576 with 4 Axes>
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
raw.plot(n_channels=64, duration=5, scalings={"eeg": 75e-6}, start=10)
# Out:
# <MNEBrowseFigure size 576x576 with 4 Axes>
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
# %matplotlib inline

from pylab import *

# %%
raw.plot()
# Out:
# <MNEBrowseFigure size 576x576 with 4 Axes>
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
# %matplotlib notebook

# %%
# The code is to be run in a Jupyter Notebook
import matplotlib.pyplot as plt
# %matplotlib notebook
plt.plot([1,2,3,4,5,6,7], [10, 50, 100, 23,15,28,45], linewidth = 3, c = 'g')
# Out:
# <div id='8e4bcf7d-5111-4530-9060-db65c4945920'></div>

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
# Grab some test data.
X, Y, Z = axes3d.get_test_data(0.05)
# Plot a surface plot.
ax.plot_surface(X, Y, Z, rstride=10, cstride=10, )
plt.show()
# Out:
# <div id='bd3fd671-6406-4a79-8dcb-81c71924ef52'></div>
